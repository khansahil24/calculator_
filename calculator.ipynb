# %%
from tkinter import *
def button_press(num):
    global equation_text
    
    equation_text=equation_text+str(num)
    equation_label.set(equation_text)
    
def equal():
    global equation_text
    try:
        total=str(eval(equation_text))
        equation_label.set(total)
        equation_text=total
    except ZeroDivisionError:
                  equation_label.set("arthemtic error")
                  equation_text=""
    except SyntaxError:
                  equation_label.set("synatx error")
                  equation_text=""

def clear():
        global equation_text
        equation_text=""
        equation_label.set(equation_text)
def percent():
    global equation_text
    
    percent=equation_text+str("/100")
    equation_label.set(percent)
    equation_text=percent
def backspace():
    global equation_text
    equation_text=equation_text[:len(equation_text)-1]
    equation_label.set(equation_text)
    
    
    

window=Tk()
window.geometry
window.config(bg="black")
window.title("calculator")

equation_text=""
equation_label=StringVar()

label=Label(window,textvariable=equation_label,font=("consoles",20),bg="grey",fg="white",width=16,height=2)
label.pack()
frame=Frame(window)
frame.pack()
button1=Button(frame,text=1,font=40,fg="white",bg="black",height=3,width=6,command=lambda:button_press(1))
button1.grid(row=0,column=0)

button2=Button(frame,text=2,font=40,fg="white",bg="black",height=3,width=6,command=lambda:button_press(2))
button2.grid(row=0,column=1)

button3=Button(frame,text=3,font=40,fg="white",bg="black",height=3,width=6,command=lambda:button_press(3))
button3.grid(row=0,column=2)

button4=Button(frame,text=4,font=40,fg="white",bg="black",height=3,width=6,command=lambda:button_press(4))
button4.grid(row=1,column=0)

button5=Button(frame,text=5,font=40,fg="white",bg="black",height=3,width=6,command=lambda:button_press(5))
button5.grid(row=1,column=1)

button6=Button(frame,text=6,font=40,fg="white",bg="black",height=3,width=6,command=lambda:button_press(6))
button6.grid(row=1,column=2)

button7=Button(frame,text=1,font=40,fg="white",bg="black",height=3,width=6,command=lambda:button_press(7))
button7.grid(row=2,column=0)

button8=Button(frame,text=8,font=40,fg="white",bg="black",height=3,width=6,command=lambda:button_press(8))
button8.grid(row=2,column=1)

button9=Button(frame,text=9,font=40,fg="white",bg="black",height=3,width=6,command=lambda:button_press(9))
button9.grid(row=2,column=2)

button0=Button(frame,text=0,font=40,fg="white",bg="black",height=3,width=6,command=lambda:button_press(0))
button0.grid(row=3,column=1)

plus=Button(frame,text="+",font=40,fg="#F34E07",bg="black",height=3,width=6,command=lambda:button_press("+"))
plus.grid(row=2,column=3)

equal=Button(frame,text="=",font=40,fg="white",bg="black",height=3,width=6,command=equal)
equal.grid(row=3,column=3)

minus=Button(frame,text="-",font=40,fg="#F34E07",bg="black",height=3,width=6,command=lambda:button_press("-"))
minus.grid(row=1,column=3)

multiply=Button(frame,text="x",font=40,fg="#F34E07",bg="black",height=3,width=6,command=lambda:button_press("*"))
multiply.grid(row=0,column=3)

divide=Button(frame,text="/",font=40,fg="#F34E07",bg="black",height=3,width=6,command=lambda:button_press("/"))
divide.grid(row=0,column=4)

percent=Button(frame,text="%",font=40,fg="#F34E07",bg="black",height=3,width=6,command=percent)
percent.grid(row=1,column=4)

clear=Button(frame,text="AC",font=40,fg="#F34E07",bg="black",height=3,width=6,command=clear)
clear.grid(row=3,column=0)

point=Button(frame,text=".",font=40,fg="white",bg="black",height=3,width=6,command=lambda:button_pres("."))
point.grid(row=3,column=2)

backspace=Button(frame,text="<xl",font=40,fg="#F34E07",bg="black",height=3,width=6,command=backspace)
backspace.grid(row=2,column=4)

window.mainloop()
